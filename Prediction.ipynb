# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set()
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import matplotlib.mlab as mlab 
# %matplotlib notebook

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
# data cleaning
sales = df.copy()

# %%
sales.isna().sum()
# Out:
# Rank              0
# Name              0
# Platform          0
# Year            271
# Genre             0
# Publisher        58
# NA_Sales          0
# EU_Sales          0
# JP_Sales          0
# Other_Sales       0
# Global_Sales      0
# dtype: int64

# %%
sales.isna().sum().sum()
# Out:
# 329

# %%
sales.replace("nan", np.nan, inplace=True)
sales = sales.dropna()
sales.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
sales.shape
# Out:
# (16291, 11)

# %%
# Convert data type
sales['Year'] = sales['Year'].astype('int32', errors='ignore')
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int32
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int32(1), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
sales.iloc[26, :]
# Out:
# Rank                                     27
# Name            Pokemon Black/Pokemon White
# Platform                                 DS
# Year                                 2010.0
# Genre                          Role-Playing
# Publisher                          Nintendo
# NA_Sales                               5.57
# EU_Sales                               3.28
# JP_Sales                               5.65
# Other_Sales                            0.82
# Global_Sales                          15.32
# Name: 26, dtype: object

# %% [markdown]
# Begining of Prediction, which market should we focus?

# %%
#data filtering
sales_after_2010 = sales[(sales.Year >= 2010) & (sales.Global_Sales > 1)]

# %%
sales_after_2010.Platform.unique()
# Out:
# array(['X360', 'PS3', 'DS', '3DS', 'PS4', 'Wii', 'XOne', 'WiiU', 'PC',
#        'PSP', 'PSV'], dtype=object)

# %%
from sklearn.preprocessing import StandardScaler

# %%
#Normalize Sales 
cols_to_norm = ['NA_Sales','EU_Sales', 'JP_Sales', 'Global_Sales']
sales_after_2010[cols_to_norm] = StandardScaler().fit_transform(sales_after_2010[cols_to_norm])
# Out:
# /var/folders/cy/p78z_yd10wb7gttsfxj36gmr0000gn/T/ipykernel_10433/2732613616.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_after_2010[cols_to_norm] = StandardScaler().fit_transform(sales_after_2010[cols_to_norm])

# %%
sales_after_2010
# Out:
#       Rank                            Name Platform    Year         Genre  \
# 15      16              Kinect Adventures!     X360  2010.0          Misc
# 16      17              Grand Theft Auto V      PS3  2013.0        Action
# 23      24              Grand Theft Auto V     X360  2013.0        Action
# 26      27     Pokemon Black/Pokemon White       DS  2010.0  Role-Playing
# 29      30  Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# ...    ...                             ...      ...     ...           ...
# 2043  2045     God of War: Ghost of Sparta      PSP  2010.0        Action
# 2044  2046               Sonic Generations      3DS  2011.0      Platform
# 2048  2050   Guitar Hero: Warriors of Rock      Wii  2010.0          Misc
# 2051  2053        The LEGO Movie Videogame      PS3  2014.0        Action
# 2053  2055                  Rayman Legends      PS4  2014.0      Platform
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 15                    Microsoft Game Studios  9.550317  3.731171  0.007515
# 16                      Take-Two Interactive  3.996664  7.830097  1.188835
# 23                      Take-Two Interactive  5.824625  4.081426 -0.283769
# 26                                  Nintendo  2.991983  2.159758  8.762228
# 29                                Activision  5.406008  3.106392 -0.170492
# ...                                      ...       ...       ...       ...
# 2043             Sony Computer Entertainment -0.608125 -0.604414 -0.332316
# 2044                                    Sega -0.587194 -0.509751 -0.364681
# 2048                              Activision -0.559286 -0.528683 -0.380864
# 2051  Warner Bros. Interactive Entertainment -0.663940 -0.490818 -0.348499
# 2053                                 Ubisoft -0.747664 -0.367756 -0.380864
#
#       Other_Sales  Global_Sales
# 15           1.67      6.922877
# 16           4.14      6.769721
# 23           1.38      4.939134
# 26           0.82      4.552596
# 29           1.32      4.348387
# ...           ...           ...
# 2043         0.21     -0.665671
# 2044         0.09     -0.665671
# 2048         0.09     -0.665671
# 2051         0.18     -0.665671
# 2053         0.18     -0.665671
#
# [562 rows x 11 columns]

# %%
sales_after_2010.Year.unique()
# Out:
# array([2010., 2013., 2011., 2015., 2012., 2014., 2016.])

# %%
#find the 
sales_after_2010['label'] = sales_after_2010[['NA_Sales', 'EU_Sales', 'JP_Sales']].max(axis=1)
# Out:
# /var/folders/cy/p78z_yd10wb7gttsfxj36gmr0000gn/T/ipykernel_10433/1714082783.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sales_after_2010['label'] = sales_after_2010[['NA_Sales', 'EU_Sales', 'JP_Sales']].max(axis=1)

# %%
#create label for each game's top-sale market
for i in range(len(sales_after_2010)):
    if sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('label')] ==sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('NA_Sales')]:
        sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('label')] = 0
    elif sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('label')] ==sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('EU_Sales')]:
        sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('label')] = 1
    elif sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('label')] ==sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('JP_Sales')]:
        sales_after_2010.iloc[i, sales_after_2010.columns.get_loc('label')] = 2

# %%
sales_after_2010
# Out:
#       Rank                            Name Platform    Year         Genre  \
# 15      16              Kinect Adventures!     X360  2010.0          Misc
# 16      17              Grand Theft Auto V      PS3  2013.0        Action
# 23      24              Grand Theft Auto V     X360  2013.0        Action
# 26      27     Pokemon Black/Pokemon White       DS  2010.0  Role-Playing
# 29      30  Call of Duty: Modern Warfare 3     X360  2011.0       Shooter
# ...    ...                             ...      ...     ...           ...
# 2043  2045     God of War: Ghost of Sparta      PSP  2010.0        Action
# 2044  2046               Sonic Generations      3DS  2011.0      Platform
# 2048  2050   Guitar Hero: Warriors of Rock      Wii  2010.0          Misc
# 2051  2053        The LEGO Movie Videogame      PS3  2014.0        Action
# 2053  2055                  Rayman Legends      PS4  2014.0      Platform
#
#                                    Publisher  NA_Sales  EU_Sales  JP_Sales  \
# 15                    Microsoft Game Studios  9.550317  3.731171  0.007515
# 16                      Take-Two Interactive  3.996664  7.830097  1.188835
# 23                      Take-Two Interactive  5.824625  4.081426 -0.283769
# 26                                  Nintendo  2.991983  2.159758  8.762228
# 29                                Activision  5.406008  3.106392 -0.170492
# ...                                      ...       ...       ...       ...
# 2043             Sony Computer Entertainment -0.608125 -0.604414 -0.332316
# 2044                                    Sega -0.587194 -0.509751 -0.364681
# 2048                              Activision -0.559286 -0.528683 -0.380864
# 2051  Warner Bros. Interactive Entertainment -0.663940 -0.490818 -0.348499
# 2053                                 Ubisoft -0.747664 -0.367756 -0.380864
#
#       Other_Sales  Global_Sales  label
# 15           1.67      6.922877    0.0
# 16           4.14      6.769721    1.0
# 23           1.38      4.939134    0.0
# 26           0.82      4.552596    2.0
# 29           1.32      4.348387    0.0
# ...           ...           ...    ...
# 2043         0.21     -0.665671    2.0
# 2044         0.09     -0.665671    2.0
# 2048         0.09     -0.665671    2.0
# 2051         0.18     -0.665671    2.0
# 2053         0.18     -0.665671    1.0
#
# [562 rows x 12 columns]

# %%
from pandas import get_dummies
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification

# %%
sales_2010 = sales_after_2010.drop(['Name','NA_Sales', 'EU_Sales', 'JP_Sales', 'Global_Sales', 'Other_Sales', 'Rank'], axis = 1)
sales_2010.loc[len(df)] = ['X360', 2016, 'Action', 'Nintendo', 1]
sales_2010 = get_dummies(sales_2010)
X_pred = sales_2010.iloc[-1, :].drop('label')
print(X_pred)
sales_2010 = sales_2010.iloc[:-1, :]
# Out:
# Year                                                2016.0
# Platform_3DS                                         False
# Platform_DS                                          False
# Platform_PC                                          False
# Platform_PS3                                         False
# Platform_PS4                                         False
# Platform_PSP                                         False
# Platform_PSV                                         False
# Platform_Wii                                         False
# Platform_WiiU                                        False
# Platform_X360                                         True
# Platform_XOne                                        False
# Genre_Action                                          True
# Genre_Adventure                                      False
# Genre_Fighting                                       False
# Genre_Misc                                           False
# Genre_Platform                                       False
# Genre_Puzzle                                         False
# Genre_Racing                                         False
# Genre_Role-Playing                                   False
# Genre_Shooter                                        False
# Genre_Simulation                                     False
# Genre_Sports                                         False
# Genre_Strategy                                       False
# Publisher_505 Games                                  False
# Publisher_Activision                                 False
# Publisher_Atlus                                      False
# Publisher_Bethesda Softworks                         False
# Publisher_Capcom                                     False
# Publisher_City Interactive                           False
# Publisher_Codemasters                                False
# Publisher_Deep Silver                                False
# Publisher_Disney Interactive Studios                 False
# Publisher_Electronic Arts                            False
# Publisher_Focus Home Interactive                     False
# Publisher_GungHo                                     False
# Publisher_Hello Games                                False
# Publisher_Konami Digital Entertainment               False
# Publisher_Level 5                                    False
# Publisher_LucasArts                                  False
# Publisher_MTV Games                                  False
# Publisher_Majesco Entertainment                      False
# Publisher_Mastertronic                               False
# Publisher_Microsoft Game Studios                     False
# Publisher_NCSoft                                     False
# Publisher_Namco Bandai Games                         False
# Publisher_Nintendo                                    True
# Publisher_Sega                                       False
# Publisher_Slightly Mad Studios                       False
# Publisher_Sony Computer Entertainment                False
# Publisher_Sony Computer Entertainment Europe         False
# Publisher_Square Enix                                False
# Publisher_THQ                                        False
# Publisher_Take-Two Interactive                       False
# Publisher_Ubisoft                                    False
# Publisher_Valve                                      False
# Publisher_Valve Software                             False
# Publisher_Warner Bros. Interactive Entertainment     False
# Name: 16598, dtype: object

# %%
sales_2010
# Out:
#         Year  label  Platform_3DS  Platform_DS  Platform_PC  Platform_PS3  \
# 15    2010.0    0.0         False        False        False         False
# 16    2013.0    1.0         False        False        False          True
# 23    2013.0    0.0         False        False        False         False
# 26    2010.0    2.0         False         True        False         False
# 29    2011.0    0.0         False        False        False         False
# ...      ...    ...           ...          ...          ...           ...
# 2043  2010.0    2.0         False        False        False         False
# 2044  2011.0    2.0          True        False        False         False
# 2048  2010.0    2.0         False        False        False         False
# 2051  2014.0    2.0         False        False        False          True
# 2053  2014.0    1.0         False        False        False         False
#
#       Platform_PS4  Platform_PSP  Platform_PSV  Platform_Wii  ...  \
# 15           False         False         False         False  ...
# 16           False         False         False         False  ...
# 23           False         False         False         False  ...
# 26           False         False         False         False  ...
# 29           False         False         False         False  ...
# ...            ...           ...           ...           ...  ...
# 2043         False          True         False         False  ...
# 2044         False         False         False         False  ...
# 2048         False         False         False          True  ...
# 2051         False         False         False         False  ...
# 2053          True         False         False         False  ...
#
#       Publisher_Slightly Mad Studios  Publisher_Sony Computer Entertainment  \
# 15                             False                                  False
# 16                             False                                  False
# 23                             False                                  False
# 26                             False                                  False
# 29                             False                                  False
# ...                              ...                                    ...
# 2043                           False                                   True
# 2044                           False                                  False
# 2048                           False                                  False
# 2051                           False                                  False
# 2053                           False                                  False
#
#       Publisher_Sony Computer Entertainment Europe  Publisher_Square Enix  \
# 15                                           False                  False
# 16                                           False                  False
# 23                                           False                  False
# 26                                           False                  False
# 29                                           False                  False
# ...                                            ...                    ...
# 2043                                         False                  False
# 2044                                         False                  False
# 2048                                         False                  False
# 2051                                         False                  False
# 2053                                         False                  False
#
#       Publisher_THQ  Publisher_Take-Two Interactive  Publisher_Ubisoft  \
# 15            False                           False              False
# 16            False                            True              False
# 23            False                            True              False
# 26            False                           False              False
# 29            False                           False              False
# ...             ...                             ...                ...
# 2043          False                           False              False
# 2044          False                           False              False
# 2048          False                           False              False
# 2051          False                           False              False
# 2053          False                           False               True
#
#       Publisher_Valve  Publisher_Valve Software  \
# 15              False                     False
# 16              False                     False
# 23              False                     False
# 26              False                     False
# 29              False                     False
# ...               ...                       ...
# 2043            False                     False
# 2044            False                     False
# 2048            False                     False
# 2051            False                     False
# 2053            False                     False
#
#       Publisher_Warner Bros. Interactive Entertainment
# 15                                               False
# 16                                               False
# 23                                               False
# 26                                               False
# 29                                               False
# ...                                                ...
# 2043                                             False
# 2044                                             False
# 2048                                             False
# 2051                                              True
# 2053                                             False
#
# [562 rows x 59 columns]

# %%
#Define the input(X) and output(y) of the model 
y = sales_2010['label'].values
X = sales_2010.drop(['label'], axis = 1).values
#Use built-in train_test_split in sklearn to split the data, 70% train, 30% test
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = 0.70, random_state = 20)

# %%
#Build a random forest classifier using Sklearn, fit the model, and predict label
RDF_1 = RandomForestClassifier(random_state = 3).fit(Xtrain, ytrain)
y_val = RDF_1.predict_proba(Xtest)
print("Validation accuracy: ", sum(pd.DataFrame(y_val).idxmax(axis=1).values == ytest ) / len(ytest) )
# Out:
# Validation accuracy:  0.649746192893401

# %%
from sklearn.decomposition import PCA

# %%
#Using PCA combine with random forest to classify
pca_X = PCA(n_components=34).fit_transform(X)
Xtrain_pca, Xtest_pca, ytrain, ytest = train_test_split(pca_X, y, test_size = 0.70, random_state = 3)

# %%
#using the transformed PCA data for prediction
RDF_2 = RandomForestClassifier(random_state = 3).fit(Xtrain_pca, ytrain)
y_val_pca = RDF_2.predict_proba(Xtest_pca)
print("Validation accuracy: ", sum(pd.DataFrame(y_val_pca).idxmax(axis=1).values == ytest ) / len(ytest) )
# Out:
# Validation accuracy:  0.6269035532994924

# %%
Xtrain[-1].shape
# Out:
# (58,)

# %%
X_pred = np.array(X_pred)

# %%
X_pred = X_pred.reshape(1, 58)

# %%
y_pred = RDF_1.predict_proba(X_pred)

# %%
y_pred
# Out:
# array([[0.28, 0.12, 0.6 ]])
